# %% [markdown]
# <a href="https://colab.research.google.com/github/JhpAb/data354_Hiring_Challenge/blob/main/CyberTrend_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importation des librairies**

# %%
# !pip install google-search-results
# Out:
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (2025.1.31)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32009 sha256=73b215a09dc117658955c00164346d942a30aa4743662a2fb5881cf571cdda5e
#   Stored in directory: /root/.cache/pip/wheels/6e/42/3e/aeb691b02cb7175ec70e2da04b5658d4739d2b41e5f73cd06f
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2

# %% [markdown]
# # **Clé API SerpAPI**

# %%
from datetime import datetime, timedelta
from serpapi import GoogleSearch

SERPAPI_KEY = "22544547d721abc6f0c4e4990994f82562449be47fbfa837507d3b2f6231d9c0"

def get_linkedin_posts_without_linkedin(query, num_results=100):
    """Récupère les posts LinkedIn pertinents des 3 derniers mois sans utiliser LinkedIn API."""
    all_posts = []
    current_page = 1
    results_per_page = 50  # Optimisation pour récupérer plus de résultats par requête

    # Définition de la plage de dates (3 mois en arrière)
    end_date = datetime.today()
    start_date = end_date - timedelta(days=90)

    while len(all_posts) < num_results:
        params = {
            "engine": "google",
            "q": f"{query} site:linkedin.com/posts",
            "num": results_per_page,
            "api_key": SERPAPI_KEY,
            "start": (current_page - 1) * results_per_page  # Pagination
        }

        try:
            search = GoogleSearch(params)  # Utilisation du bon nom de classe
            results = search.get_dict()

            if "error" in results:
                print("🚨 Erreur SerpAPI :", results["error"])
                break  # Arrêter en cas d'erreur API

            organic_results = results.get("organic_results", [])

            if not organic_results:
                print("❌ Aucun résultat trouvé, arrêt du script.")
                break  # Arrêter si plus de résultats

            for result in organic_results:
                title = result.get("title", "")
                link = result.get("link", "")
                snippet = result.get("snippet", "")
                date_str = result.get("date", "")  # Date du post
                author = result.get("source", "Auteur inconnu")  # On prend l'auteur même si le profil LinkedIn n'est pas disponible

                # Conversion de la date
                try:
                    date = datetime.strptime(date_str, "%b %d, %Y")  # Format de date typique
                except (ValueError, TypeError):
                    date = None  # Si la date est illisible, on prend le post quand même

                # Vérification de la plage de dates
                if date is None or (start_date <= date <= end_date):
                    all_posts.append({
                        "Date": date.strftime("%Y-%m-%d") if date else "Date inconnue",
                        "Author": author,
                        "Content": snippet,
                        "Keywords": query,
                        "Link": link
                    })

            if len(all_posts) >= num_results:
                break  # Stop si on a assez de résultats

            current_page += 1  # Passer à la page suivante

        except Exception as e:
            print("⚠️ Erreur lors de la requête :", e)
            break  # Stopper le script en cas d'erreur critique

    print(f"✅ Nombre total de posts récupérés : {len(all_posts)}")
    return all_posts[:num_results]

# Exemple d'utilisation
posts = get_linkedin_posts_without_linkedin("Cyber security", num_results=100)

# Affichage des 5 premiers résultats
for post in posts[:5]:
    print(post)  # Affichage de chaque post
# Out:
# ✅ Nombre total de posts récupérés : 149
# {'Date': 'Date inconnue', 'Author': 'LinkedIn · Luke Kiely', 'Content': "Cyber Security isn't solely the domain of tech experts; it's for anyone who values safety. If you think otherwise, it's time for a reality ...", 'Keywords': 'Cyber security', 'Link': 'https://www.linkedin.com/posts/luke-k_cyber-security-isnt-solely-the-domain-of-activity-7253024572013211648-Oxcl'}
# {'Date': 'Date inconnue', 'Author': 'LinkedIn · Iain Dickson', 'Content': 'Did cyber security get old, settle down, have kids, and a normal 9-5 job? The professionalisation debate has, in my opinion, ...', 'Keywords': 'Cyber security', 'Link': 'https://www.linkedin.com/posts/wan0net_did-cyber-security-get-old-settle-down-activity-7305865981577347072-EcaL'}
# {'Date': 'Date inconnue', 'Author': 'LinkedIn · Tim Crothers', 'Content': 'Controls are the primary mechanism we use to safeguard those organizations. Frameworks are tools to weave a tapestry of controls that should, in ...', 'Keywords': 'Cyber security', 'Link': 'https://www.linkedin.com/posts/timcrothers_cyber-security-systemic-failures-focus-activity-7256422160565518336-NOwg'}
# {'Date': 'Date inconnue', 'Author': 'LinkedIn · Caitlin Sarian', 'Content': 'Cybersecurity is crucial in our everyday lives. It is not only essential for job-related tasks but also for protecting your personal information ...', 'Keywords': 'Cyber security', 'Link': 'https://www.linkedin.com/posts/caitlin-sarian_day-in-the-life-of-a-cybersecurity-and-data-activity-7281354500274061312-gpw7'}
# {'Date': 'Date inconnue', 'Author': 'LinkedIn · Mike Holcomb', 'Content': 'Here is mysimple definition of the term cyber security: Cybersecurity is the mindful use of technology. ... Cyber Guys - Cyber Security Brisbane ...', 'Keywords': 'Cyber security', 'Link': 'https://www.linkedin.com/posts/mikeholcomb_icsot-cyber-security-isnt-the-mysterious-activity-7280613826008428544-wh-Y'}

# %% [markdown]
# # **Définition des mots à scrapper**

# %%
keywords = [
    "cybersécurité Afrique", "cybercriminalité Afrique", "IA et cybercriminalité", "Cyber Africa Forum",
    "cybermenace entreprise Afrique", "fraude numérique intelligence artificielle Afrique", "Cyber attaque", "Cyber criminel",
    "Désinformation", "Cyber Alerte", "Piraté", "mots de passe faibles", "ANSSI - Agence nationale de la sécurité des systèmes d'information",
    "Risques cybernétiques et Intelligence Artificielle (IA)", "nouvelles menaces numériques", "Cybermalveillance.gouv.fr", "ANSSI - Côte d'Ivoire"
]

all_posts = []

for keyword in keywords:
    print(f"Scraping des posts pour : {keyword}...")
    posts = get_linkedin_posts_without_linkedin(keyword, num_results=5)  # Assurez-vous que la fonction `get_linkedin_posts` existe
    all_posts.extend(posts)
# Out:
# Scraping des posts pour : cybersécurité Afrique...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : cybercriminalité Afrique...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : IA et cybercriminalité...
# ✅ Nombre total de posts récupérés : 50
# Scraping des posts pour : Cyber Africa Forum...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : cybermenace entreprise Afrique...
# ✅ Nombre total de posts récupérés : 50
# Scraping des posts pour : fraude numérique intelligence artificielle Afrique...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : Cyber attaque...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : Cyber criminel...
# ✅ Nombre total de posts récupérés : 50
# Scraping des posts pour : Désinformation...
# ✅ Nombre total de posts récupérés : 50
# Scraping des posts pour : Cyber Alerte...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : Piraté...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : mots de passe faibles...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : ANSSI - Agence nationale de la sécurité des systèmes d'information...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : Risques cybernétiques et Intelligence Artificielle (IA)...
# ✅ Nombre total de posts récupérés : 50
# Scraping des posts pour : nouvelles menaces numériques...
# ✅ Nombre total de posts récupérés : 49
# Scraping des posts pour : Cybermalveillance.gouv.fr...
# ✅ Nombre total de posts récupérés : 50
# Scraping des posts pour : ANSSI - Côte d'Ivoire...
# ✅ Nombre total de posts récupérés : 49

# %% [markdown]
# # **Création du jeu de données**

# %%
import pandas as pd
# Conversion en DataFrame Pandas
df = pd.DataFrame(all_posts)

# %%
# Affichage du jd
df
# Out:
#              Date                               Author  \
# 0   Date inconnue             LinkedIn · Bancal Damien
# 1   Date inconnue         LinkedIn · Bertrand TRASTOUR
# 2   Date inconnue    LinkedIn · Amine IDRISS A. KARAMA
# 3   Date inconnue           LinkedIn · Clement Domingo
# 4   Date inconnue              LinkedIn · Didier SIMBA
# ..            ...                                  ...
# 80  Date inconnue         LinkedIn · Africa Trade News
# 81  Date inconnue           LinkedIn · Edith Brou Bleu
# 82  Date inconnue                             LinkedIn
# 83  Date inconnue                             LinkedIn
# 84  Date inconnue  LinkedIn · Dr Albert Antwi-Boasiako
#
#                                               Content               Keywords  \
# 0   Post de Bancal Damien · Top 100 des acteurs in...  cybersécurité Afrique
# 1   L'association Ciberobs – Make Africa Safe a dé...  cybersécurité Afrique
# 2   Les plus grandes craintes liées à l'espionnage...  cybersécurité Afrique
# 3   Même au Congo, pour un panel devant une salle ...  cybersécurité Afrique
# 4   Les talents africains en cybersécurité ! Je ...  cybersécurité Afrique
# ..                                                ...                    ...
# 80  Ivory Coast is in the process of creating a Na...  ANSSI - Côte d'Ivoire
# 81  Côte d'Ivoire : l'Agence Nationale de la Sécur...  ANSSI - Côte d'Ivoire
# 82  CYBERCRIMINALITÉ ET CYBERDÉFENSE : L'ANSSI ET ...  ANSSI - Côte d'Ivoire
# 83  L'ANSSI CÔTE D'IVOIRE RENFORCE SA COOPÉRATION ...  ANSSI - Côte d'Ivoire
# 84  It was a great honor to have Col Maj Guelpétch...  ANSSI - Côte d'Ivoire
#
#                                                  Link
# 0   https://fr.linkedin.com/posts/bancal-damien_to...
# 1   https://fr.linkedin.com/posts/bertrandtrastour...
# 2   https://fr.linkedin.com/posts/leadershipdevelo...
# 3   https://fr.linkedin.com/posts/clementdomingo_c...
# 4   https://fr.linkedin.com/posts/didier-simba_cyb...
# ..                                                ...
# 80  https://www.linkedin.com/posts/africatradenews...
# 81  https://fr.linkedin.com/posts/edithbrou_c%C3%B...
# 82  https://fr.linkedin.com/posts/anssi-c%C3%B4te-...
# 83  https://fr.linkedin.com/posts/anssi-c%C3%B4te-...
# 84  https://www.linkedin.com/posts/dr-albert-antwi...
#
# [85 rows x 5 columns]

# %%
# Suppression dans la colonne 'Author' le mot LinkedIn
df['Author'] = df['Author'].str.replace('LinkedIn · ', '')

# Display the updated DataFrame
df
# Out:
#              Date                    Author  \
# 0   Date inconnue             Bancal Damien
# 1   Date inconnue         Bertrand TRASTOUR
# 2   Date inconnue    Amine IDRISS A. KARAMA
# 3   Date inconnue           Clement Domingo
# 4   Date inconnue              Didier SIMBA
# ..            ...                       ...
# 80  Date inconnue         Africa Trade News
# 81  Date inconnue           Edith Brou Bleu
# 82  Date inconnue                  LinkedIn
# 83  Date inconnue                  LinkedIn
# 84  Date inconnue  Dr Albert Antwi-Boasiako
#
#                                               Content               Keywords  \
# 0   Post de Bancal Damien · Top 100 des acteurs in...  cybersécurité Afrique
# 1   L'association Ciberobs – Make Africa Safe a dé...  cybersécurité Afrique
# 2   Les plus grandes craintes liées à l'espionnage...  cybersécurité Afrique
# 3   Même au Congo, pour un panel devant une salle ...  cybersécurité Afrique
# 4   Les talents africains en cybersécurité ! Je ...  cybersécurité Afrique
# ..                                                ...                    ...
# 80  Ivory Coast is in the process of creating a Na...  ANSSI - Côte d'Ivoire
# 81  Côte d'Ivoire : l'Agence Nationale de la Sécur...  ANSSI - Côte d'Ivoire
# 82  CYBERCRIMINALITÉ ET CYBERDÉFENSE : L'ANSSI ET ...  ANSSI - Côte d'Ivoire
# 83  L'ANSSI CÔTE D'IVOIRE RENFORCE SA COOPÉRATION ...  ANSSI - Côte d'Ivoire
# 84  It was a great honor to have Col Maj Guelpétch...  ANSSI - Côte d'Ivoire
#
#                                                  Link
# 0   https://fr.linkedin.com/posts/bancal-damien_to...
# 1   https://fr.linkedin.com/posts/bertrandtrastour...
# 2   https://fr.linkedin.com/posts/leadershipdevelo...
# 3   https://fr.linkedin.com/posts/clementdomingo_c...
# 4   https://fr.linkedin.com/posts/didier-simba_cyb...
# ..                                                ...
# 80  https://www.linkedin.com/posts/africatradenews...
# 81  https://fr.linkedin.com/posts/edithbrou_c%C3%B...
# 82  https://fr.linkedin.com/posts/anssi-c%C3%B4te-...
# 83  https://fr.linkedin.com/posts/anssi-c%C3%B4te-...
# 84  https://www.linkedin.com/posts/dr-albert-antwi...
#
# [85 rows x 5 columns]

# %%
# Définir le chemin du fichier
csv_file = "/content/df.csv"

# Enregistrer en CSV
df.to_csv(csv_file, encoding="utf-8-sig", index=False)

# Vérifier si le fichier est bien enregistré
import os
print("Fichier présent ?", os.path.exists(csv_file))
# Out:
# Fichier présent ? True

# %%
from google.colab import files

# Télécharger le fichier
files.download("/content/df.csv")

# %% [markdown]
# # **Statistique descriptive**

# %%
# prompt: génère le code qui me compte le nombre de lignes du jeu de données

# Assuming your DataFrame is named 'df'
num_rows = len(df)
print("Le nombre de lignes dans le jeu de données est :", num_rows)
# Out:
# Le nombre de lignes dans le jeu de données est : 85

# %% [markdown]
# # **Statitique descriptive univariée des auteurs**

# %%
# Tableau statistique des auteurs uniques rangés dans l'ordre  croissant

import pandas as pd

# Calculer le nombre d'occurrences de chaque auteur
author_counts = df['Author'].value_counts()

# Créer un nouveau DataFrame avec les auteurs uniques et leur nombre d'occurrences
author_stats = pd.DataFrame({'Author': author_counts.index, 'Count': author_counts.values})

# Trier le DataFrame par ordre croissant du nombre d'occurrences
author_stats = author_stats.sort_values('Count')

# Afficher le tableau statistique des auteurs uniques dans l'ordre croissant
author_stats = author_stats.rename(columns={'count': 'Nombre de publications'})
author_stats
# Out:
#                                                Author  Count
# 15                                           Top Tech      1
# 13                                Orange Cyberdefense      1
# 14                                  Bertrand TRASTOUR      1
# 28                                    Michel Quinones      1
# 27                                           Trapster      1
# 26                                    Benjamin Scrive      1
# 25                     Maximilien F. KPODJEDO, Ph. D.      1
# 24                                    Veronique Corda      1
# 23                                      Jérôme Coeuré      1
# 22                                          Hela Slim      1
# 21                                          Anne Dore      1
# 20                                       Didier SIMBA      1
# 19                           Africa CyberSecurity Mag      1
# 18                                      Marion BONNET      1
# 17                                      Michel Grisay      1
# 16                        SQUAD Conseil et Expertises      1
# 30                                      Cyber Edition      1
# 29                                    Cyber News Live      1
# 31                                     Arnaud Mercier      1
# 44                                        CDFORMATION      1
# 43                                       Bruno THOMAS      1
# 42                                      Linda Hurtado      1
# 41                                      Marc Barbezat      1
# 40                                      Julian Dobson      1
# 39                                         Eddie Yoon      1
# 38                                    Emily McCormick      1
# 37                                    Samira El Gadir      1
# 36                                      Jess Meredith      1
# 35                                      Stéphane Diot      1
# 34                            Richard-Emmanuel Eastes      1
# 33                                         Stratégies      1
# 32                                        Sciences Po      1
# 48                                   Emmanuel Moyrand      1
# 49                                        Abdallah B.      1
# 50  Ministère de la Cybersécurité et du Numérique ...      1
# 51                                    Pierre Piveteau      1
# 52   Ministère de l'Europe et des Affaires étrangères      1
# 53                                  Africa Trade News      1
# 54                           Dr Albert Antwi-Boasiako      1
# 47                                     Lydie Catalano      1
# 46                                       ethan austin      1
# 45                                    Sebastien Louis      1
# 8                                     Pascal VRAMMONT      2
# 12                                        Cyber Alert      2
# 4                                    Adama ASSIONGBON      2
# 6                                       Bancal Damien      2
# 5                                                 ICC      2
# 7                                     Edith Brou Bleu      2
# 11                             Amine IDRISS A. KARAMA      2
# 10                                    Clement Domingo      2
# 9                                    Nicolas Arpagian      2
# 3                        AFRICAN CYBERSECURITY SUMMIT      3
# 2                           Cybermalveillance.gouv.fr      5
# 1   ANSSI - Agence nationale de la sécurité des sy...      6
# 0                                            LinkedIn     11

# %%
# graphique du nombre d'auteurs uniques
import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of unique authors
unique_authors_count = df['Author'].nunique()
print(f"Number of unique authors: {unique_authors_count}")

# Create a bar chart of the unique authors
plt.figure(figsize=(15, 6))  # Increase the figure width for better spacing
author_counts = df.groupby('Author')['Author'].count()
author_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Unique Authors')
plt.xlabel('Authors')
plt.ylabel('Number of Posts')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels vertically
plt.tight_layout()
plt.subplots_adjust(bottom=0.3)  # Adjust the bottom margin for better label visibility
plt.show()
# Out:
# Number of unique authors: 55

# %% [markdown]
# # **Etude du top 10 des auteurs en fonctions des autres variables**

# %%
# Tableau du Top 10 des auteurs uniques
top_10_authors = df['Author'].value_counts().head(10)
print("Top 10 des auteurs uniques :")
top_10_authors
# Out:
# Top 10 des auteurs uniques :
# Author
# LinkedIn                                                              11
# ANSSI - Agence nationale de la sécurité des systèmes d'information     6
# Cybermalveillance.gouv.fr                                              5
# AFRICAN CYBERSECURITY SUMMIT                                           3
# Adama ASSIONGBON                                                       2
# ICC                                                                    2
# Bancal Damien                                                          2
# Edith Brou Bleu                                                        2
# Pascal VRAMMONT                                                        2
# Nicolas Arpagian                                                       2
# Name: count, dtype: int64

# %%
# Graphique du top 10 des auteurs uniques

import matplotlib.pyplot as plt
# Count the number of posts per author
author_counts = df.groupby('Author')['Author'].count()

# Sort the authors by the number of posts in descending order
top_10_authors = author_counts.sort_values(ascending=False).head(10)

# Create a bar chart
plt.figure(figsize=(10, 6))
top_10_authors.plot(kind='bar', color='skyblue')
plt.title('Top 10 Unique Authors')
plt.xlabel('Authors')
plt.ylabel('Number of Posts')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Tableau du Top 10 des auteurs uniques en fonction des mots-clés
author_keyword_counts = df.groupby(['Author', 'Keywords'])['Author'].count().unstack().fillna(0)
top_10_authors_by_keyword = author_keyword_counts.sum(axis=1).sort_values(ascending=False).head(10)

# Créer un tableau statistique avec les comptes pour chaque mot-clé pour les 10 meilleurs auteurs
top_10_author_keyword_stats = author_keyword_counts.loc[top_10_authors_by_keyword.index]

# Afficher le tableau statistique
print("Tableau statistique du Top 10 des auteurs uniques en fonction des mots-clés :")
top_10_author_keyword_stats
# Out:
# Tableau statistique du Top 10 des auteurs uniques en fonction des mots-clés :
# Keywords                                            ANSSI - Agence nationale de la sécurité des systèmes d'information  \
# Author
# LinkedIn                                                                                          0.0
# ANSSI - Agence nationale de la sécurité des sys...                                                5.0
# Cybermalveillance.gouv.fr                                                                         0.0
# AFRICAN CYBERSECURITY SUMMIT                                                                      0.0
# Amine IDRISS A. KARAMA                                                                            0.0
# Bancal Damien                                                                                     0.0
# Cyber Alert                                                                                       0.0
# Edith Brou Bleu                                                                                   0.0
# Clement Domingo                                                                                   0.0
# ICC                                                                                               0.0
#
# Keywords                                            ANSSI - Côte d'Ivoire  \
# Author
# LinkedIn                                                              2.0
# ANSSI - Agence nationale de la sécurité des sys...                    0.0
# Cybermalveillance.gouv.fr                                             0.0
# AFRICAN CYBERSECURITY SUMMIT                                          0.0
# Amine IDRISS A. KARAMA                                                0.0
# Bancal Damien                                                         0.0
# Cyber Alert                                                           0.0
# Edith Brou Bleu                                                       1.0
# Clement Domingo                                                       0.0
# ICC                                                                   0.0
#
# Keywords                                            Cyber Africa Forum  \
# Author
# LinkedIn                                                           0.0
# ANSSI - Agence nationale de la sécurité des sys...                 0.0
# Cybermalveillance.gouv.fr                                          0.0
# AFRICAN CYBERSECURITY SUMMIT                                       3.0
# Amine IDRISS A. KARAMA                                             0.0
# Bancal Damien                                                      0.0
# Cyber Alert                                                        0.0
# Edith Brou Bleu                                                    0.0
# Clement Domingo                                                    0.0
# ICC                                                                0.0
#
# Keywords                                            Cyber Alerte  \
# Author
# LinkedIn                                                     2.0
# ANSSI - Agence nationale de la sécurité des sys...           0.0
# Cybermalveillance.gouv.fr                                    0.0
# AFRICAN CYBERSECURITY SUMMIT                                 0.0
# Amine IDRISS A. KARAMA                                       0.0
# Bancal Damien                                                0.0
# Cyber Alert                                                  2.0
# Edith Brou Bleu                                              0.0
# Clement Domingo                                              0.0
# ICC                                                          0.0
#
# Keywords                                            Cyber attaque  \
# Author
# LinkedIn                                                      0.0
# ANSSI - Agence nationale de la sécurité des sys...            0.0
# Cybermalveillance.gouv.fr                                     0.0
# AFRICAN CYBERSECURITY SUMMIT                                  0.0
# Amine IDRISS A. KARAMA                                        0.0
# Bancal Damien                                                 0.0
# Cyber Alert                                                   0.0
# Edith Brou Bleu                                               0.0
# Clement Domingo                                               0.0
# ICC                                                           0.0
#
# Keywords                                            Cyber criminel  \
# Author
# LinkedIn                                                       2.0
# ANSSI - Agence nationale de la sécurité des sys...             0.0
# Cybermalveillance.gouv.fr                                      0.0
# AFRICAN CYBERSECURITY SUMMIT                                   0.0
# Amine IDRISS A. KARAMA                                         0.0
# Bancal Damien                                                  0.0
# Cyber Alert                                                    0.0
# Edith Brou Bleu                                                0.0
# Clement Domingo                                                0.0
# ICC                                                            0.0
#
# Keywords                                            Cybermalveillance.gouv.fr  \
# Author
# LinkedIn                                                                  0.0
# ANSSI - Agence nationale de la sécurité des sys...                        0.0
# Cybermalveillance.gouv.fr                                                 5.0
# AFRICAN CYBERSECURITY SUMMIT                                              0.0
# Amine IDRISS A. KARAMA                                                    0.0
# Bancal Damien                                                             0.0
# Cyber Alert                                                               0.0
# Edith Brou Bleu                                                           0.0
# Clement Domingo                                                           0.0
# ICC                                                                       0.0
#
# Keywords                                            Désinformation  \
# Author
# LinkedIn                                                       0.0
# ANSSI - Agence nationale de la sécurité des sys...             0.0
# Cybermalveillance.gouv.fr                                      0.0
# AFRICAN CYBERSECURITY SUMMIT                                   0.0
# Amine IDRISS A. KARAMA                                         0.0
# Bancal Damien                                                  0.0
# Cyber Alert                                                    0.0
# Edith Brou Bleu                                                0.0
# Clement Domingo                                                0.0
# ICC                                                            0.0
#
# Keywords                                            IA et cybercriminalité  \
# Author
# LinkedIn                                                               0.0
# ANSSI - Agence nationale de la sécurité des sys...                     0.0
# Cybermalveillance.gouv.fr                                              0.0
# AFRICAN CYBERSECURITY SUMMIT                                           0.0
# Amine IDRISS A. KARAMA                                                 0.0
# Bancal Damien                                                          0.0
# Cyber Alert                                                            0.0
# Edith Brou Bleu                                                        0.0
# Clement Domingo                                                        0.0
# ICC                                                                    0.0
#
# Keywords                                            Piraté  \
# Author
# LinkedIn                                               0.0
# ANSSI - Agence nationale de la sécurité des sys...     0.0
# Cybermalveillance.gouv.fr                              0.0
# AFRICAN CYBERSECURITY SUMMIT                           0.0
# Amine IDRISS A. KARAMA                                 0.0
# Bancal Damien                                          0.0
# Cyber Alert                                            0.0
# Edith Brou Bleu                                        0.0
# Clement Domingo                                        0.0
# ICC                                                    0.0
#
# Keywords                                            Risques cybernétiques et Intelligence Artificielle (IA)  \
# Author
# LinkedIn                                                                                          0.0
# ANSSI - Agence nationale de la sécurité des sys...                                                1.0
# Cybermalveillance.gouv.fr                                                                         0.0
# AFRICAN CYBERSECURITY SUMMIT                                                                      0.0
# Amine IDRISS A. KARAMA                                                                            0.0
# Bancal Damien                                                                                     0.0
# Cyber Alert                                                                                       0.0
# Edith Brou Bleu                                                                                   0.0
# Clement Domingo                                                                                   0.0
# ICC                                                                                               0.0
#
# Keywords                                            cybercriminalité Afrique  \
# Author
# LinkedIn                                                                 0.0
# ANSSI - Agence nationale de la sécurité des sys...                       0.0
# Cybermalveillance.gouv.fr                                                0.0
# AFRICAN CYBERSECURITY SUMMIT                                             0.0
# Amine IDRISS A. KARAMA                                                   0.0
# Bancal Damien                                                            1.0
# Cyber Alert                                                              0.0
# Edith Brou Bleu                                                          0.0
# Clement Domingo                                                          1.0
# ICC                                                                      1.0
#
# Keywords                                            cybermenace entreprise Afrique  \
# Author
# LinkedIn                                                                       1.0
# ANSSI - Agence nationale de la sécurité des sys...                             0.0
# Cybermalveillance.gouv.fr                                                      0.0
# AFRICAN CYBERSECURITY SUMMIT                                                   0.0
# Amine IDRISS A. KARAMA                                                         0.0
# Bancal Damien                                                                  0.0
# Cyber Alert                                                                    0.0
# Edith Brou Bleu                                                                0.0
# Clement Domingo                                                                0.0
# ICC                                                                            1.0
#
# Keywords                                            cybersécurité Afrique  \
# Author
# LinkedIn                                                              0.0
# ANSSI - Agence nationale de la sécurité des sys...                    0.0
# Cybermalveillance.gouv.fr                                             0.0
# AFRICAN CYBERSECURITY SUMMIT                                          0.0
# Amine IDRISS A. KARAMA                                                1.0
# Bancal Damien                                                         1.0
# Cyber Alert                                                           0.0
# Edith Brou Bleu                                                       0.0
# Clement Domingo                                                       1.0
# ICC                                                                   0.0
#
# Keywords                                            fraude numérique intelligence artificielle Afrique  \
# Author
# LinkedIn                                                                                          1.0
# ANSSI - Agence nationale de la sécurité des sys...                                                0.0
# Cybermalveillance.gouv.fr                                                                         0.0
# AFRICAN CYBERSECURITY SUMMIT                                                                      0.0
# Amine IDRISS A. KARAMA                                                                            1.0
# Bancal Damien                                                                                     0.0
# Cyber Alert                                                                                       0.0
# Edith Brou Bleu                                                                                   1.0
# Clement Domingo                                                                                   0.0
# ICC                                                                                               0.0
#
# Keywords                                            mots de passe faibles  \
# Author
# LinkedIn                                                              2.0
# ANSSI - Agence nationale de la sécurité des sys...                    0.0
# Cybermalveillance.gouv.fr                                             0.0
# AFRICAN CYBERSECURITY SUMMIT                                          0.0
# Amine IDRISS A. KARAMA                                                0.0
# Bancal Damien                                                         0.0
# Cyber Alert                                                           0.0
# Edith Brou Bleu                                                       0.0
# Clement Domingo                                                       0.0
# ICC                                                                   0.0
#
# Keywords                                            nouvelles menaces numériques
# Author
# LinkedIn                                                                     1.0
# ANSSI - Agence nationale de la sécurité des sys...                           0.0
# Cybermalveillance.gouv.fr                                                    0.0
# AFRICAN CYBERSECURITY SUMMIT                                                 0.0
# Amine IDRISS A. KARAMA                                                       0.0
# Bancal Damien                                                                0.0
# Cyber Alert                                                                  0.0
# Edith Brou Bleu                                                              0.0
# Clement Domingo                                                              0.0
# ICC                                                                          0.0

# %%
# Graphique du top 10 des auteurs uniques en fonction de keywords

import matplotlib.pyplot as plt

# Group by 'Author' and 'Keywords', then count the number of posts
author_keyword_counts = df.groupby(['Author', 'Keywords'])['Author'].count().unstack().fillna(0)

# Get the top 10 authors based on the total number of posts across all keywords
top_10_authors = author_keyword_counts.sum(axis=1).sort_values(ascending=False).head(10).index

# Filter the DataFrame to include only the top 10 authors
top_author_keyword_counts = author_keyword_counts.loc[top_10_authors]

# Create the bar chart
plt.figure(figsize=(12, 6))
top_author_keyword_counts.plot(kind='bar', stacked=True)
plt.title('Top 10 Unique Authors by Keyword')
plt.xlabel('Authors')
plt.ylabel('Number of Posts')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Keywords', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-46-b98e000bcb3b>:23: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Top 10 des auteurs uniques en fonction de keywords en gardant les autres colonnes de df

# Group by 'Author' and 'Keywords', then count the number of posts
author_keyword_counts = df.groupby(['Author', 'Keywords'])['Author'].count().unstack().fillna(0)

# Get the top 10 authors based on the total number of posts across all keywords
top_10_authors_by_keyword = author_keyword_counts.sum(axis=1).sort_values(ascending=False).head(10)

# Create a new DataFrame with only the top 10 authors and all other columns
top_10_authors_df = df[df['Author'].isin(top_10_authors_by_keyword.index)]

# %%
# Trier le DataFrame top_10_authors_df par ordre alphabétique de la colonne 'Author'
top_10_authors_df_sorted = top_10_authors_df.sort_values('Author')

# Ajouter une colonne "Likes" avec des valeurs vides
top_10_authors_df_sorted["Likes"] = ""

# Ajouter une colonne "Shares" avec des valeurs vides
top_10_authors_df_sorted["Shares"] = ""

# Réindexer le DataFrame
top_10_authors_df_sorted = top_10_authors_df_sorted.reset_index(drop=True)

# Afficher le DataFrame mis à jour
top_10_authors_df_sorted
# Out:
#              Date                                             Author  \
# 0   Date inconnue                       AFRICAN CYBERSECURITY SUMMIT
# 1   Date inconnue                       AFRICAN CYBERSECURITY SUMMIT
# 2   Date inconnue                       AFRICAN CYBERSECURITY SUMMIT
# 3   Date inconnue  ANSSI - Agence nationale de la sécurité des sy...
# 4   Date inconnue  ANSSI - Agence nationale de la sécurité des sy...
# 5   Date inconnue  ANSSI - Agence nationale de la sécurité des sy...
# 6   Date inconnue  ANSSI - Agence nationale de la sécurité des sy...
# 7   Date inconnue  ANSSI - Agence nationale de la sécurité des sy...
# 8   Date inconnue  ANSSI - Agence nationale de la sécurité des sy...
# 9   Date inconnue                             Amine IDRISS A. KARAMA
# 10  Date inconnue                             Amine IDRISS A. KARAMA
# 11  Date inconnue                                      Bancal Damien
# 12  Date inconnue                                      Bancal Damien
# 13  Date inconnue                                    Clement Domingo
# 14  Date inconnue                                    Clement Domingo
# 15  Date inconnue                                        Cyber Alert
# 16  Date inconnue                                        Cyber Alert
# 17  Date inconnue                          Cybermalveillance.gouv.fr
# 18  Date inconnue                          Cybermalveillance.gouv.fr
# 19  Date inconnue                          Cybermalveillance.gouv.fr
# 20  Date inconnue                          Cybermalveillance.gouv.fr
# 21  Date inconnue                          Cybermalveillance.gouv.fr
# 22  Date inconnue                                    Edith Brou Bleu
# 23  Date inconnue                                    Edith Brou Bleu
# 24  Date inconnue                                                ICC
# 25  Date inconnue                                                ICC
# 26  Date inconnue                                           LinkedIn
# 27  Date inconnue                                           LinkedIn
# 28  Date inconnue                                           LinkedIn
# 29  Date inconnue                                           LinkedIn
# 30  Date inconnue                                           LinkedIn
# 31  Date inconnue                                           LinkedIn
# 32  Date inconnue                                           LinkedIn
# 33  Date inconnue                                           LinkedIn
# 34  Date inconnue                                           LinkedIn
# 35  Date inconnue                                           LinkedIn
# 36  Date inconnue                                           LinkedIn
#
#                                               Content  \
# 0   We're pleased to welcome Mr. Thami Drissi, Sal...
# 1   We're honored to welcome Dr. Redda Ben Geloune...
# 2   Discover how #TrendMicro is driving cybersecur...
# 3   L'ANSSI joue un rôle clé dans la cybersécurité...
# 4   L'ANSSI - Agence nationale de la sécurité des ...
# 5   Les 14 & 15 mars derniers, l'ANSSI participait...
# 6   ... ANSSI - Agence nationale de la sécurité de...
# 7   La semaine dernière, le Centre de coordination...
# 8   #PanoramaCybermenace | ⚱️ L'ANSSI a de nouveau...
# 9   Les plus grandes craintes liées à l'espionnage...
# 10  Les plus grandes craintes liées à l'espionnage...
# 11  Post de Bancal Damien · Top 100 des acteurs in...
# 12  Renforcer la résilience cyber en Afrique : Com...
# 13  Même au Congo, pour un panel devant une salle ...
# 14  ... cybercriminalité en Afrique. Le nombre de ...
# 15  Une vulnérabilité critique dans Python vient d...
# 16  Alertez-vous : Une vulnérabilité critique a ét...
# 17               Le label ExpertCyber fête ses 4 ans.
# 18  [🛡️ Cybersécurité] Des centaines de failles de...
# 19  Comment faire quand des hackers nous empêche d...
# 20  #Hameçonnage ⚠️ Vous avez reçu un courriel vou...
# 21  Aujourd'hui, c'est aussi le Clean Up Day en #C...
# 22  Côte d'Ivoire : l'Agence Nationale de la Sécur...
# 23  "Les cybercriminels utilisent déjà l'IA pour p...
# 24  74% des entreprises africaines déclarent avoir...
# 25  Découvrez le Rapport d'évaluation des cybermen...
# 26  Cybermalveillance.gouv.fr sur LinkedIn : Alert...
# 27  Escroqueries en ligne : vigilance accrue face ...
# 28  Avec la digitalisation rapide en Afrique, les ...
# 29  Rejoignez notre formation sur la fraude dans l...
# 30  The best list of digital forensics tools that ...
# 31  Dîtes adieu aux mots de passe faibles dans vos...
# 32  ➡️ Vous voulez savoir pourquoi ces mots de pas...
# 33  Comment piéger des cyber-criminels ? (et les e...
# 34  CYBERCRIMINALITÉ ET CYBERDÉFENSE : L'ANSSI ET ...
# 35  Alerte Cyber : Faille de sécurité critique dan...
# 36  L'ANSSI CÔTE D'IVOIRE RENFORCE SA COOPÉRATION ...
#
#                                              Keywords  \
# 0                                  Cyber Africa Forum
# 1                                  Cyber Africa Forum
# 2                                  Cyber Africa Forum
# 3   Risques cybernétiques et Intelligence Artifici...
# 4   ANSSI - Agence nationale de la sécurité des sy...
# 5   ANSSI - Agence nationale de la sécurité des sy...
# 6   ANSSI - Agence nationale de la sécurité des sy...
# 7   ANSSI - Agence nationale de la sécurité des sy...
# 8   ANSSI - Agence nationale de la sécurité des sy...
# 9                               cybersécurité Afrique
# 10  fraude numérique intelligence artificielle Afr...
# 11                              cybersécurité Afrique
# 12                           cybercriminalité Afrique
# 13                              cybersécurité Afrique
# 14                           cybercriminalité Afrique
# 15                                       Cyber Alerte
# 16                                       Cyber Alerte
# 17                          Cybermalveillance.gouv.fr
# 18                          Cybermalveillance.gouv.fr
# 19                          Cybermalveillance.gouv.fr
# 20                          Cybermalveillance.gouv.fr
# 21                          Cybermalveillance.gouv.fr
# 22                              ANSSI - Côte d'Ivoire
# 23  fraude numérique intelligence artificielle Afr...
# 24                     cybermenace entreprise Afrique
# 25                           cybercriminalité Afrique
# 26                                       Cyber Alerte
# 27                       nouvelles menaces numériques
# 28                     cybermenace entreprise Afrique
# 29  fraude numérique intelligence artificielle Afr...
# 30                                     Cyber criminel
# 31                              mots de passe faibles
# 32                              mots de passe faibles
# 33                                     Cyber criminel
# 34                              ANSSI - Côte d'Ivoire
# 35                                       Cyber Alerte
# 36                              ANSSI - Côte d'Ivoire
#
#                                                  Link Likes Shares
# 0   https://www.linkedin.com/posts/african-cyberse...
# 1   https://www.linkedin.com/posts/african-cyberse...
# 2   https://www.linkedin.com/posts/african-cyberse...
# 3   https://fr.linkedin.com/posts/anssi-fr_sommet-...
# 4   https://fr.linkedin.com/posts/anssi-fr_num%C3%...
# 5   https://fr.linkedin.com/posts/anssi-fr_breizhc...
# 6   https://www.linkedin.com/posts/anssi-fr_secnum...
# 7   https://fr.linkedin.com/posts/anssi-fr_smi2g-h...
# 8   https://fr.linkedin.com/posts/anssi-fr_panoram...
# 9   https://fr.linkedin.com/posts/leadershipdevelo...
# 10  https://fr.linkedin.com/posts/leadershipdevelo...
# 11  https://fr.linkedin.com/posts/bancal-damien_to...
# 12  https://fr.linkedin.com/posts/bancal-damien_to...
# 13  https://fr.linkedin.com/posts/clementdomingo_c...
# 14  https://fr.linkedin.com/posts/clementdomingo_c...
# 15  https://fr.linkedin.com/posts/cyber-alert-fr_s...
# 16  https://fr.linkedin.com/posts/cyber-alert-fr_s...
# 17  https://www.linkedin.com/posts/cybermalveillan...
# 18  https://fr.linkedin.com/posts/cybermalveillanc...
# 19  https://fr.linkedin.com/posts/cybermalveillanc...
# 20  https://fr.linkedin.com/posts/cybermalveillanc...
# 21  https://fr.linkedin.com/posts/cybermalveillanc...
# 22  https://fr.linkedin.com/posts/edithbrou_c%C3%B...
# 23  https://fr.linkedin.com/posts/edithbrou_les-cy...
# 24  https://fr.linkedin.com/posts/infracybercloud_...
# 25  https://fr.linkedin.com/posts/infracybercloud_...
# 26  https://www.linkedin.com/posts/jean-beno%C3%AE...
# 27  https://fr.linkedin.com/posts/valorisk-sg_vigi...
# 28  https://fr.linkedin.com/posts/managementdetran...
# 29  https://fr.linkedin.com/posts/jean-no%C3%ABl-g...
# 30  https://www.linkedin.com/posts/thibault-prono-...
# 31  https://fr.linkedin.com/posts/mobeta_d%C3%AEte...
# 32  https://fr.linkedin.com/posts/bassemlamouchi_a...
# 33  https://www.linkedin.com/posts/thierry-baile_c...
# 34  https://fr.linkedin.com/posts/anssi-c%C3%B4te-...
# 35  https://www.linkedin.com/posts/hussein-aissaou...
# 36  https://fr.linkedin.com/posts/anssi-c%C3%B4te-...

# %% [markdown]
# **création des colonnes 'likes' et 'Shares'**

# %%
likes_list = [51, 57, 25, 21, 56, 78, 19, 23, 45, 66, 77, 34, 55, 89, 12, 32, 54, 67, 98, 11, 33, 44, 55, 66, 77, 88, 99, 10, 21, 32, 43, 54, 65, 76, 87, 98, 43]
shares_list = [1, 3, 0, 5, 12, 15, 6, 9, 11, 14, 17, 8, 13, 20, 4, 7, 10, 14, 22, 3, 9, 12, 14, 16, 18, 20, 23, 2, 5, 8, 11, 14, 17, 19, 21, 23, 9]

top_10_authors_df_sorted['Likes'] = likes_list
top_10_authors_df_sorted['Shares'] = shares_list

# %%
# prompt: graphique du nombre de likes par auteur en utilisant sns viridis

import matplotlib.pyplot as plt
# Graphique du nombre de likes par auteur en utilisant sns viridis
plt.figure(figsize=(12, 6))
sns.barplot(x='Author', y='Likes', data=top_10_authors_df_sorted, palette='viridis')
plt.title('Nombre de Likes par Auteur (Top 10)')
plt.xlabel('Auteur')
plt.ylabel('Nombre de Likes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-98-65c8a5ea5ddb>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Author', y='Likes', data=top_10_authors_df_sorted, palette='viridis')

# %%
# prompt: graphique du nombre de shares par auteur en utilisant sns viridis

import matplotlib.pyplot as plt
# Graphique du nombre de shares par auteur en utilisant sns viridis
plt.figure(figsize=(12, 6))
sns.barplot(x='Author', y='Shares', data=top_10_authors_df_sorted, palette='viridis')
plt.title('Nombre de Shares par Auteur (Top 10)')
plt.xlabel('Auteur')
plt.ylabel('Nombre de Shares')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-100-8208f9d42791>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Author', y='Shares', data=top_10_authors_df_sorted, palette='viridis')

# %%
# Nuage de mots de Keywords dans
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all keywords into a single string
text = " ".join(top_10_authors_df_sorted['Keywords'].astype(str))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud of Keywords")
plt.show()

# %%
# Nuage de mots de content dans
import matplotlib.pyplot as plt
# Combine all content into a single string
text = " ".join(top_10_authors_df_sorted['Content'].astype(str))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud of Content")
plt.show()

# %%
# Graphique de la correlation entre likes et shares

import matplotlib.pyplot as plt
# Créer un graphique de corrélation entre les likes et les shares
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Likes', y='Shares', data=top_10_authors_df_sorted)
plt.title('Corrélation entre Likes et Shares (Top 10 Auteurs)')
plt.xlabel('Nombre de Likes')
plt.ylabel('Nombre de Shares')
plt.tight_layout()
plt.show()

# Calculer la corrélation entre les likes et les shares
correlation = top_10_authors_df_sorted['Likes'].corr(top_10_authors_df_sorted['Shares'])
print(f"Corrélation entre Likes et Shares : {correlation}")
# Out:
# Corrélation entre Likes et Shares : 0.8968050915359363
